# %% [markdown]
# # Q-Step Exercises
#
# Learn to load, explore, manipulate, visualise, and model data using Python.

# %% [markdown]
# ## 1. Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Load the dataset

# %%
df = pd.read_csv('qstep_dataset.csv')
df.head()

# %% [markdown]
# ### Exercise 1
# Display the **last 5 rows** of the dataset.

# %%
# Your code here

# %% [markdown]
# ## 3. Explore the dataset

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ### Exercise 2
# Find the **mean income**.

# %%
# Your code here

# %% [markdown]
# ## 4. Selecting columns

# %%
df['income'].head()

# %% [markdown]
# ### Exercise 3
# Select the **age** column.

# %%
# Your code here

# %% [markdown]
# ## 5. Filtering rows

# %%
df[df['age'] > 40].head()

# %% [markdown]
# ### Exercise 4
# Find all individuals with **income greater than 60000**.

# %%
# Your code here

# %% [markdown]
# ## 6. Grouping data

# %%
df.groupby('education')['income'].mean()

# %% [markdown]
# ### Exercise 5
# Calculate the **average income by gender**.

# %%
# Your code here

# %% [markdown]
# ## 7. Visualising data

# %%
df['income'].hist()
plt.show()

# %%
sns.scatterplot(x='age', y='income', data=df)
plt.show()

# %% [markdown]
# ### Exercise 6
# Create a **boxplot of income by education level**.

# %%
# Your code here

# %% [markdown]
# ## 8. Regression

# %% [markdown]
# ### Final Exercise
# Using statsmodels, run a regression predicting income from age and education.

# %%
# Your code here
